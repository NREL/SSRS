# %%
from herbie.archive import Herbie
from typing import Dict, Tuple
import pygrib
import yaml
import numpy as np
# Out:
# /Users/akey/anaconda3/envs/ssrs_env/lib/python3.10/site-packages/herbie/archive.py:70: UserWarning: herbie xarray accessors could not be imported.You are probably missing the Carpenter_Workshop.If you want to use these functions, try`pip install git+https://github.com/blaylockbk/Carpenter_Workshop.git`
#   warnings.warn(

# %%
H = Herbie("2021-03-01 12:00", model="hrrr", product="sfc", fxx=0)
# Out:
# 🏋🏻‍♂️ Found 2021-Mar-01 12:00 UTC F00 [HRRR] [product=sfc] GRIB2 file from aws and index file from aws.

# %%
H.download("TMP:500 mb")

# %%
H.xarray("TMP:500 mb", remove_grib=False)

# %%
H.download("HGT:500 mb")

# %%
Hx = H.xarray("HGT:500 mb", remove_grib=False)

# %%
Hx

# %%
print(Hx['gh'][100, 100].values)

# %%
H.download("TMP")

# %% [markdown]
# ## Focus on temp at 500 mb

# %%
Hx = H.xarray("TMP:500 mb", remove_grib=False)
# Out:
# 👨🏻‍🏭 Created directory: [/Users/akey/data/hrrr/20210301]
# 📇 Download subset: [HRRR] model [sfc] product run at 2021-Mar-01 12:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210301/conus/hrrr.t12z.wrfsfcf00.grib2
#    1: GRIB_message=15  :TMP:500 mb:anl

# %%
Hx
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-03-01T12:00:00
#     step                 timedelta64[ns] 00:00:00
#     isobaricInhPa        float64 500.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t                    (y, x) float32 ...
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
# ...

# %%
latc = Hx.coords['latitude']
lonc = Hx.coords['longitude']

# %%
# Hx.t.loc[{'longitude': lonc[(lonc >= 237.280472) & (lonc <= 237.33381)]}]
latc_mask = (latc >= 41.6) & (latc <= 41.8)
lonc_mask = (lonc >= 287.23) & (lonc <= 287.24)
mask = latc_mask & lonc_mask
Hx.t.where(mask)

# %%
Hx.t.where(mask).sum() / float(mask.sum())
