# %%
from herbie.archive import Herbie
from typing import Dict, Tuple
import pygrib
import yaml
import numpy as np

# %%
H = Herbie("2021-01-01 12:00", model="hrrr", product="sfc", fxx=0)
# Out:
# 🏋🏻‍♂️ Found 2021-Jan-01 12:00 UTC F00 [HRRR] [product=sfc] GRIB2 file from aws and index file from aws.

# %%
H.download("TMP:500 mb")
# Out:
# 📇 Download subset: [HRRR] model [sfc] product run at 2021-Jan-01 12:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210101/conus/hrrr.t12z.wrfsfcf00.grib2
#    1: GRIB_message=15  :TMP:500 mb:anl

# %%
H.xarray("TMP:500 mb", remove_grib=False)
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-01-01T12:00:00
#     step                 timedelta64[ns] 00:00:00
#     isobaricInhPa        float64 500.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t                    (y, x) float32 ...
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/akey/data/hrrr/20210101/hrrr.t12z.wrfsfcf...

# %%
H.download("HGT:500 mb")
# Out:
# 📇 Download subset: [HRRR] model [sfc] product run at 2021-Jan-01 12:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210101/conus/hrrr.t12z.wrfsfcf00.grib2
#    1: GRIB_message=14  :HGT:500 mb:anl

# %%
Hx = H.xarray("HGT:500 mb", remove_grib=False)

# %%
Hx
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-01-01T12:00:00
#     step                 timedelta64[ns] 00:00:00
#     isobaricInhPa        float64 500.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     gh                   (y, x) float32 ...
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/akey/data/hrrr/20210101/hrrr.t12z.wrfsfcf...

# %%
print(Hx['gh'][100, 100].values)
# Out:
# 5800.7866

# %%
H.download("TMP")
# Out:
# 📇 Download subset: [HRRR] model [sfc] product run at 2021-Jan-01 12:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210101/conus/hrrr.t12z.wrfsfcf00.grib2
#    1: GRIB_message=15  :TMP:500 mb:anl
#    2: GRIB_message=20  :TMP:700 mb:anl
#    3: GRIB_message=26  :TMP:850 mb:anl
#    4: GRIB_message=30  :TMP:925 mb:anl
#    5: GRIB_message=34  :TMP:1000 mb:anl
#    6: GRIB_message=64  :TMP:surface:anl
#    7: GRIB_message=71  :TMP:2 m above ground:anl

# %% [markdown]
# ## Focus on temp at 500 mb

# %%
Hx = H.xarray("TMP:500 mb", remove_grib=False)

# %%
Hx
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-01-01T12:00:00
#     step                 timedelta64[ns] 00:00:00
#     isobaricInhPa        float64 500.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t                    (y, x) float32 ...
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/akey/data/hrrr/20210101/hrrr.t12z.wrfsfcf...

# %%
latc = Hx.coords['latitude']
lonc = Hx.coords['longitude']

# %%
# Hx.t.loc[{'longitude': lonc[(lonc >= 237.280472) & (lonc <= 237.33381)]}]
latc_mask = (latc >= 41.6) & (latc <= 41.8)
lonc_mask = (lonc >= 287.23) & (lonc <= 287.24)
mask = latc_mask & lonc_mask
Hx.t.where(mask)
# Out:
# <xarray.DataArray 't' (y: 1059, x: 1799)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#     time           datetime64[ns] 2021-01-01T12:00:00
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  float64 500.0
#     latitude       (y, x) float64 21.14 21.15 21.15 21.16 ... 47.86 47.85 47.84
#     longitude      (y, x) float64 237.3 237.3 237.3 237.4 ... 299.0 299.0 299.1
#     valid_time     datetime64[ns] 2021-01-01T12:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     GRIB_paramId:                             130
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      1905141
#     GRIB_typeOfLevel:                         isobaricInhPa
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     GRIB_gridType:                            lambert
#     GRIB_DxInMetres:                          3000.0
#     GRIB_DyInMetres:                          3000.0
#     GRIB_LaDInDegrees:                        38.5
#     GRIB_Latin1InDegrees:                     38.5
#     GRIB_Latin2InDegrees:                     38.5
#     GRIB_LoVInDegrees:                        262.5
#     GRIB_NV:                                  0
#     GRIB_Nx:                                  1799
#     GRIB_Ny:                                  1059
#     GRIB_cfName:                              air_temperature
#     GRIB_cfVarName:                           t
#     GRIB_gridDefinitionDescription:           Lambert Conformal can be secant...
#     GRIB_iScansNegatively:                    0
#     GRIB_jPointsAreConsecutive:               0
#     GRIB_jScansPositively:                    1
#     GRIB_latitudeOfFirstGridPointInDegrees:   21.138123
#     GRIB_latitudeOfSouthernPoleInDegrees:     0.0
#     GRIB_longitudeOfFirstGridPointInDegrees:  237.280472
#     GRIB_longitudeOfSouthernPoleInDegrees:    0.0
#     GRIB_missingValue:                        9999
#     GRIB_name:                                Temperature
#     GRIB_parameterName:                       Temperature
#     GRIB_parameterUnits:                      K
#     GRIB_shortName:                           t
#     GRIB_stepRange:                           0
#     GRIB_units:                               K
#     long_name:                                Temperature
#     units:                                    K
#     standard_name:                            air_temperature
#     grid_mapping:                             gribfile_projection

# %%
Hx.t.where(mask).sum() / float(mask.sum())
# Out:
# <xarray.DataArray 't' ()>
# array(254.81626892)
# Coordinates:
#     time           datetime64[ns] 2021-01-01T12:00:00
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  float64 500.0
#     valid_time     datetime64[ns] 2021-01-01T12:00:00
